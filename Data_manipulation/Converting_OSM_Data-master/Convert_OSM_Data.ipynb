# %% [markdown]
# # Extracting and Converting OpenStreetMap data in Python
# OpenStreetMap is an open source collaborative mapping project that has tons of really valuable and freely available data. However, in order to use it in most applications it needs to be converted to another format. If working with large amounts of data, the best approach is to use a tool such as ```imposm``` or ```osm2pgsql```, both of which first import the data into a PostgreSQL/PostGIS database. From there the data can be queried or exported. However, if working with smaller amounts of data where a spatial database is not necessary, there is a quick and easy way to extract data from an OSM file (XML based) using a driver in the Python OGR library. I demonstrate this approach below using a sample of data in my neighborhood in San Francisco.
#
# The OSM file that I use in this example can be downloaded from the following link on the OpenStreetMap website (http://www.openstreetmap.org/export#map=17/37.78292/-122.46336). The area I downloaded represents the Inner Richmond neighborhood, roughly between 6th and 3rd Avenues, along Geary and Clement.
#
# Below, I go through an example where I read in the points layer from the OSM data using the OGR driver, extract relevant attributes and location, convert the data to a GeoPandas GeoDataFrame, and then plot it on a map.
#
# First I import the necessary modules - ``ogr`` is used to read in the OSM data, ```shapely``` is used to convert the geometries, ```geopandas``` is used to store the data and geometry, and ```matplotlib``` is used to plot it.

# %%
conda install -c conda-forge gdal
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                                                          /failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - anaconda==2021.05 -> python[version='3.7.10|3.9.4|3.8.8',build='hdb3f193_0|hdb3f193_5']
#   - appdirs -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.7.*|3.8.*|3.9.*|3.10.*',build='0_73_pypy|1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy']
#   - atomicwrites -> python[version='2.7.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - bkcharts -> python[version='3.4.*|>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='3.10.*|3.4.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.8.*|3.7.*|3.9.*',build='0_73_pypy|1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|>=3.10,<3.11.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='0_73_pypy|1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy']
#   - colorama -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.10.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.8.*|3.9.*|3.7.*|3.4.*|>=3.6|>=3.5|<=3.3',build='0_73_pypy|1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy']
#   - diff-match-patch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - gevent -> python[version='3.10.*|3.4.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.9.*|3.8.*',build='0_73_pypy|1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|0_73_pypy']
#   - glob2 -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - html5lib -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - intervaltree -> python[version='2.7.*|3.5.*|3.6.*']
#   - jdcal -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - more-itertools -> python[version='3.4.*|>=3.9,<3.10.0a0']
#   - olefile -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - pycodestyle -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - pyflakes -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - three-merge -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - tifffile -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - zope.event -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libffi conflicts for:
# requests -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# flask -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# qtconsole -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyzmq -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pip -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# notebook -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# tifffile -> python[version='>=3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sortedcollections -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# llvmlite -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# click -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# wcwidth -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# entrypoints -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# prompt_toolkit -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# patsy -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# xlwt -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# textdistance -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# py -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# intervaltree -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# python-jsonrpc-server -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anyio -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pexpect -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backports.tempfile -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cytoolz -> pypy3.8[version='>=7.3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# urllib3 -> python[version='<4.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# astropy -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ujson -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cairo -> libglib[version='>=2.70.2,<3.0a0'] -> libffi[version='>=3.0.0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# pycparser -> python[version='2.7.*|>=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anaconda-clean -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# navigator-updater -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sympy -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# xlsxwriter -> python[version='>=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# multipledispatch -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pathspec -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# testpath -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anaconda-project -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# alabaster -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# werkzeug -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pycosat -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pytest -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backports -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyxdg -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# dask -> python[version='>=3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# wrapt -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mpmath -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mkl-service -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# scikit-image -> pypy3.7[version='>=7.3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numpydoc -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyparsing -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter_console -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# bottleneck -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nbclient -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# distributed -> python[version='>=3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyqt -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# spyder -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# networkx -> python[version='>=3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyterlab -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# zope.interface -> pypy3.8[version='>=7.3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pytables -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-build -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyls-black -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-repo-cli -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# astroid -> pypy3.9[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# importlib-metadata -> pypy3.9[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# itsdangerous -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jsonschema -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cython -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-websupport -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# snowballstemmer -> python[version='>=2'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pandas -> pypy3.9[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyflakes -> python[version='2.7.*|>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# seaborn -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# keyring -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# async_generator -> python[version='>2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nest-asyncio -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# qtawesome -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# atomicwrites -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# matplotlib -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# qtpy -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# six -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyyaml -> pypy3.9[version='>=7.3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda[version='>=4.11.0'] -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# qt -> libglib[version='>=2.70.2,<3.0a0'] -> libffi[version='>=3.0.0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# pywavelets -> pypy3.9[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# argh -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# wurlitzer -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nbclassic -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# colorama -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backcall -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyterlab_pygments -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# toml -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nbconvert -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# imageio -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mkl_random -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyls-spyder -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gstreamer -> libffi[version='>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0']
# singledispatch -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# python-libarchive-c -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mock -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pluggy -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sniffio -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# zict -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jinja2 -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# py-lief -> pypy3.7[version='>=7.3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinx -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# zope.event -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sortedcontainers -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gdal -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# argon2-cffi -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0|<3.3.0.a0|>=3.3']
# openpyxl -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# isort -> python[version='>=3.6,<4.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# tblib -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backports.shutil_get_terminal_size -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numba -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# unicodecsv -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# et_xmlfile -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# heapdict -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# defusedxml -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anaconda-navigator -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyodbc -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pylint -> python[version='>=3.7.2'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# fastcache -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pango -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# pep8 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mkl_fft -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# msgpack-python -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# bokeh -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cffi -> libffi[version='<3.3.0.a0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# zipp -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ply -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nbformat -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# glib -> libffi[version='<3.3.0.a0|>=3.0.0|>=3.2.1,<3.3.0a0|>=3.3|>=3.3,<3.4.0a0|>=3.2.1,<3.3a0']
# docutils -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# typed-ast -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# setuptools -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# iniconfig -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numexpr -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# prompt-toolkit -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# fsspec -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter-packaging -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# widgetsnbextension -> pypy3.7[version='>=7.3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-package-handling -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# python-dateutil -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ipython_genutils -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# zope -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# certifi -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-env -> python=3.5 -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3a0']
# locket -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ptyprocess -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gdal -> libffi[version='>=3.3,<3.4.0a0']
# anaconda-client -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# chardet -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# dask-core -> python[version='>=3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ipywidgets -> python[version='>=3.3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter_server -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# soupsieve -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# xlrd -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# send2trash -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anaconda==2021.05 -> cffi==1.14.5=py37h261ae71_0 -> libffi[version='>=3.3,<3.4.0a0']
# cycler -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# yapf -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mistune -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# path.py -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# boto -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# backports.weakref -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nltk -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pycodestyle -> python[version='2.7.*|>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# watchdog -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# scipy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ruamel_yaml -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# black -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pydocstyle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mccabe -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gst-plugins-base -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='>=3.0.0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0|>=3.3']
# pyopenssl -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# secretstorage -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# beautifulsoup4 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyterlab_server -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# tqdm -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jeepney -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# html5lib -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gevent -> cffi[version='>=1.11.5'] -> libffi[version='3.2.*|<3.3.0.a0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# clyent -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# parso -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# rope -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cloudpickle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# simplegeneric -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pygments -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# packaging -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyerfa -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# statsmodels -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# toolz -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# three-merge -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cffi -> python[version='>=3.6,<3.7.0a0'] -> libffi=3.2
# python-language-server -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# flake8 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ipykernel -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gstreamer -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='<3.3.0.a0|>=3.0.0|>=3.3|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0']
# pkginfo -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# python=3.8 -> libffi[version='>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jdcal -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# bleach -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-content-trust -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# partd -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# olefile -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pickleshare -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# anaconda==2021.05 -> libffi==3.3=he6710b0_2
# pango -> libglib[version='>=2.70.2,<3.0a0'] -> libffi[version='>=3.0.0|>=3.2.1,<3.3.0a0|>=3.4.2,<3.5.0a0|>=3.3']
# conda-token -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# asn1crypto -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numpy-base -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# glob2 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# more-itertools -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# json5 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# jupyter_client -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# webencodings -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# appdirs -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# conda-verify -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# brotlipy -> cffi[version='>=1.0.0'] -> libffi[version='3.2.*|<3.3.0.a0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# greenlet -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# psutil -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# autopep8 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# babel -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# decorator -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# h5py -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# prometheus_client -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# mypy_extensions -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pytz -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# idna -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# qdarkstyle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# joblib -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# rtree -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pathlib2 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# diff-match-patch -> python -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# cryptography -> cffi[version='>=1.12'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0|<3.3.0.a0']
# dbus -> libglib[version='>=2.70.2,<3.0a0'] -> libffi[version='<3.3.0.a0|>=3.0.0|>=3.2.1,<3.3.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.3,<3.4.0a0|>=3.2.1,<3.3a0']
# glib -> gettext[version='>=0.19.8.1,<1.0a0'] -> libffi[version='3.2.*|>=3.4.2,<3.5.0a0']
# typing_extensions -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# imagesize -> python[version='>=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# threadpoolctl -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# gmpy2 -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# future -> pypy3.9[version='>=7.3.8'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# filelock -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# sqlalchemy -> pypy3.8[version='>=7.3.9'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# path -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pycurl -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# traitlets -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# contextlib2 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# lxml -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# xmltodict -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# spyder-kernels -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# harfbuzz -> libglib[version='>=2.70.2,<3.0a0'] -> libffi[version='<3.3.0.a0|>=3.0.0|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.3|>=3.2.1,<3.3a0']
# regex -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# bkcharts -> python=3.6 -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# nose -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pillow -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# pyrsistent -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
#
# Package zlib conflicts for:
# partd -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# intervaltree -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# sphinxcontrib-websupport -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# unicodecsv -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# libpng -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# libllvm10 -> zlib[version='>=1.2.11,<1.3.0a0']
# llvmlite -> zlib[version='>=1.2.11,<1.3.0a0']
# heapdict -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# asn1crypto -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# pylint -> python[version='>=3.7.2'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# qt -> libxml2[version='>=2.9.12,<2.10.0a0'] -> zlib[version='1.2.11|1.2.8.*|>=1.2.12,<1.3.0a0|1.2.8']
# gevent -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# async_generator -> python[version='>2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# pyls-spyder -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# jupyterlab -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# hdf5 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8']
# mypy_extensions -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# pyls-black -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# autopep8 -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# conda-repo-cli -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# pathlib2 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# black -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0']
# fastcache -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# openpyxl -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# qdarkstyle -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# flask -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# pluggy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# multipledispatch -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# llvmlite -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# numpy-base -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# conda[version='>=4.11.0'] -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0']
# py-lief -> pypy3.7[version='>=7.3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# atomicwrites -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# idna -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# imagesize -> python[version='>=3.4'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# six -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# regex -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# pip -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0']
# sortedcontainers -> python[version='>=2.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# diff-match-patch -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# conda-env -> python=3.5 -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.11.*|1.2.8']
# pyrsistent -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# imageio -> pillow[version='>=8.3.2'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# babel -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# setuptools -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# sympy -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# qtconsole -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# pillow -> zlib[version='1.2.*|1.2.11|1.2.11.*|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# argh -> python -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|1.2.11.*|>=1.2.12,<1.3.0a0']
# pyparsing -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# qtawesome -> python[version='>=3.6'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|1.2.8|>=1.2.12,<1.3.0a0|1.2.11.*']
# cython -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# gdal -> hdf5[version='>=1.12.1,<1.12.2.0a0'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# zict -> python[version='>=3.7'] -> zlib[version='1.2.*|1.2.11|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|1.2.8|1.2.11.*']
# ...
# libtiff -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
#
# Package json-rpc conflicts for:
# pyls-black -> python-language-server -> json-rpc
# pyls-spyder -> python-language-server -> json-rpc
# python-language-server -> json-rpc
#
# Package ucx conflicts for:
# h5py -> openmpi[version='>=4.1.2,<5.0a0'] -> ucx[version='>=1.12.1,<1.13.0a0']
# hdf5 -> openmpi[version='>=4.1,<4.2.0a0'] -> ucx[version='>=1.12.1,<1.13.0a0']
#
# Package keyutils conflicts for:
# curl -> krb5[version='>=1.19.3,<1.20.0a0'] -> keyutils[version='>=1.6.1,<2.0a0']
# krb5 -> keyutils[version='>=1.6.1,<2.0a0']
# libcurl -> krb5[version='>=1.19.3,<1.20.0a0'] -> keyutils[version='>=1.6.1,<2.0a0']
#
# Package s3fs conflicts for:
# dask -> distributed[version='>=1.16.0'] -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
# distributed -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
#
# Package path conflicts for:
# anaconda==2021.05 -> path==15.1.2[build='py37h06a4308_0|py39h06a4308_0|py38h06a4308_0']
# anaconda==2021.05 -> path.py==12.5.0=0 -> path
# path.py -> path[version='<13.2']
#
# Package libarchive conflicts for:
# conda-build -> libarchive
# conda-package-handling -> python-libarchive-c -> libarchive
# conda-verify -> conda-package-handling[version='>=1.0.4'] -> libarchive[version='>=3.3.3']
# anaconda==2021.05 -> libarchive==3.4.2=h62408e4_0
# conda[version='>=4.11.0'] -> conda-package-handling[version='>=1.3.0'] -> libarchive[version='>=3.3.3']
# python-libarchive-c -> libarchive
# conda-package-handling -> libarchive[version='>=3.3.3']
# anaconda==2021.05 -> python-libarchive-c==2.9=pyhd3eb1b0_1 -> libarchive
# conda-build -> conda-package-handling[version='>=1.3'] -> libarchive[version='>=3.3.3']
#
# Package brotli conflicts for:
# tifffile -> imagecodecs[version='>=2021.7.30'] -> brotli[version='>=1.0.7,<1.1.0a0|>=1.0.9,<1.1.0a0|>=1.0.9,<2.0a0']
# anaconda==2021.05 -> brotli==1.0.9=he6710b0_2
# matplotlib-base -> fonttools[version='>=4.22.0'] -> brotli[version='>=1.0.1']
# anaconda==2021.05 -> brunsli==0.1=h2531618_0 -> brotli[version='>=1.0.9,<1.1.0a0|>=1.0.9,<2.0a0']
#
# Package tbb4py conflicts for:
# numpy-base -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py27h81de0dd_0 -> tbb4py
#
# Package rtree conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> rtree[version='>=0.8.3']
# anaconda==2021.05 -> rtree==0.9.7[build='py39h06a4308_1|py37h06a4308_1|py38h06a4308_1']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
#
# Package conda-content-trust conflicts for:
# anaconda-navigator -> conda-token -> conda-content-trust
# conda-token -> conda-content-trust
#
# Package pathlib conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26'] -> pathlib
# tifffile -> pathlib
#
# Package curio conflicts for:
# jupyter_server -> anyio[version='>=2.0.2,<3'] -> curio
# anyio -> curio
#
# Package libogg conflicts for:
# gst-plugins-base -> libogg
# gst-plugins-base -> libvorbis[version='>=1.3.7,<1.4.0a0'] -> libogg[version='>=1.3.2,<1.4.0a0|>=1.3.4,<1.4.0a0|>=1.3.2,<2.0a0']
#
# Package mpmath conflicts for:
# anaconda==2021.05 -> sympy==1.8=py37h06a4308_0 -> mpmath[version='>=0.19']
# sympy -> mpmath[version='>=0.19']
# anaconda==2021.05 -> mpmath==1.2.1[build='py37h06a4308_0|py39h06a4308_0|py38h06a4308_0']
#
# Package watchdog conflicts for:
# anaconda==2021.05 -> watchdog==1.0.2[build='py39h06a4308_1|py37h06a4308_1|py38h06a4308_1']
# spyder -> watchdog[version='>=0.10.3|>=0.10.3,<2.0.0']
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> watchdog[version='>=0.10.3,<2.0.0']
#
# Package llvmlite conflicts for:
# numba -> llvmlite[version='0.20.*|0.21.*|0.21.0|0.23.0|0.27.*|>=0.28.0,<0.29.0a0|>=0.28.0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0,<0.33|>=0.33.0,<0.34|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0|>=0.37.0,<0.38.0a0|>=0.38.0,<0.39.0a0|>=0.27.0,<0.28.0a0|>=0.26.0,<0.27.0a0|>=0.25.0,<0.26.0a0|>=0.21.0,<0.21.1.0a0|>=0.33.0|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.32.1|>=0.32.1,<0.33.0a0|>=0.32.0|>=0.32.0,<0.33.0a0|>=0.31.0|0.24.*|0.23.*|0.22.*',build=*_1]
# anaconda==2021.05 -> numba==0.53.1=py37ha9443f7_0 -> llvmlite[version='>=0.36.0,<0.37.0a0']
# anaconda==2021.05 -> llvmlite==0.36.0[build='py37h612dafd_4|py39h612dafd_4|py38h612dafd_4']
#
# Package pyls-black conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> pyls-black[version='>=0.4.6']
# anaconda==2021.05 -> pyls-black==0.4.6=hd3eb1b0_0
# spyder -> pyls-black[version='>=0.4.6']
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
#
# Package hypothesis conflicts for:
# astropy -> pytest-astropy -> hypothesis[version='>=5.1']
# attrs -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
#
# Package python-lsp-server conflicts for:
# spyder -> python-lsp-server[version='>=1.2.1,<1.3.0|>=1.2.2,<1.3.0|>=1.3.1,<1.4.0|>=1.3.2,<1.4.0|>=1.4.1,<1.5.0']
# spyder -> pyls-spyder[version='>=0.4.0'] -> python-lsp-server[version='>=1.0.1|>=1.4.0']
#
# Package patchelf conflicts for:
# conda-build -> patchelf
# anaconda==2021.05 -> patchelf==0.12=h2531618_1
#
# Package intervaltree conflicts for:
# anaconda==2021.05 -> intervaltree==3.1.0=py_0
# spyder -> intervaltree[version='>=3.0.2']
# anaconda==2021.05 -> spyder==4.2.5=py37h06a4308_0 -> intervaltree[version='>=3.0.2']
#
# Package et_xmlfile conflicts for:
# openpyxl -> et_xmlfile
# anaconda==2021.05 -> openpyxl==3.0.7=pyhd3eb1b0_0 -> et_xmlfile
# anaconda==2021.05 -> et_xmlfile==1.0.1=py_1001
#
# Package qt-webengine conflicts for:
# spyder -> pyqtwebengine[version='<5.16'] -> qt-webengine[version='>=5.15.4,<5.16.0a0']
# qt -> qt-webengine=5.15.4
#
# Package pkginfo conflicts for:
# anaconda==2021.05 -> pkginfo==1.7.0[build='py37h06a4308_0|py39h06a4308_0|py38h06a4308_0']
# conda-build -> pkginfo
#
# Package notebook-shim conflicts for:
# nbclassic -> notebook-shim[version='>=0.1.0']
# jupyterlab -> nbclassic[version='>=0.2,<1'] -> notebook-shim[version='>=0.1.0']
#
# Package backports.tempfile conflicts for:
# scikit-image -> pooch[version='>=0.5.2'] -> backports.tempfile
# conda-build -> conda-verify -> backports.tempfile
# conda-verify -> backports.tempfile
#
# Package pathtools conflicts for:
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
# watchdog -> pathtools[version='>=0.1.1']
#
# Package nspr conflicts for:
# qt -> nss[version='>=3.74,<4.0a0'] -> nspr[version='>=4.22,<5.0a0|>=4.27|>=4.30,<5.0a0|>=4.33,<5|>=4.33,<5.0a0']
# qt -> nspr[version='>=4.20,<5.0a0|>=4.28,<5.0a0|>=4.29,<5.0a0|>=4.32,<5.0a0']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.31=0
#   - feature:|@/linux-64::__glibc==2.31=0
#   - argon2-cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - astropy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bitarray -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - blas -> libgfortran-ng -> __glibc[version='>=2.17']
#   - blosc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bottleneck -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - c-ares -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - conda-package-handling -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - curl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cython -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cytoolz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fastcache -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gdal -> libgdal==3.5.0=h844f3f6_1 -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - gevent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gmp -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gmpy2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - greenlet -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - h5py -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - hdf5 -> libgfortran-ng -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - jbig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lazy-object-proxy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libarchive -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libcurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libev -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - liblief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libllvm10 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libspatialindex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libssh2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libtool -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libwebp-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxslt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - llvmlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lxml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lzo -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl-service -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_fft -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_random -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mpc -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - mpfr -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - msgpack-python -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - numba -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numexpr -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - patchelf -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - psutil -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - py-lief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycosat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyerfa -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyqt -> qt-main[version='>=5.15.3,<5.16.0a0'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - pyrsistent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pytables -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - python=3.8 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pywavelets -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - qt -> qt-main=5.15.2 -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - readline -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - regex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ripgrep -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-image -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-learn -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scipy -> libgfortran-ng -> __glibc[version='>=2.17']
#   - sip -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - statsmodels -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tbb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tifffile -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tornado -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - typed-ast -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ujson -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - unixodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - wrapt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zope.interface -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.31
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import ogr
import shapely
from shapely.geometry import *
import geopandas as gpd
import matplotlib.pyplot as plt
import IPython.display as display

osm = """
<iframe width="500" height="400" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" \
src="http://www.openstreetmap.org/export/embed.html?bbox=\
-122.47178%2C37.77859%2C-122.45493%2C37.78724&amp;layer=mapnik" \
style="border: 1px solid black"></iframe><br/><small><a \
href="http://www.openstreetmap.org/#map=17/37.78292/-122.46336">View Larger Map</a></small>
"""
display.HTML(osm)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d098bd04d019> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import ogr
#       3 import shapely
#       4 from shapely.geometry import *
#       5 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'ogr'

# %% [markdown]
# I then define the relevant OGR driver, which in this case is called "OSM". I use that driver to open my OSM file, which categorizes the features into 5 layers:
#
# 1. **points** : "node" features
# 2. **lines** : "way" features that are recognized as non-area.
# 3. **multilinestrings** : "relation" features that form a multilinestring
# 4. **multipolygons** : "relation" features that form a multipolygon and "way" features that are recognized as area.
# 5. **other_relations** : "relation" features that do not belong to the above 2 layers.
#
# I use the ```GetLayer``` method to extract the "points" layer and iterate over the features in this layer, storing them in a list. As shown below, there are 39 features in this point layer.

# %%
driver=ogr.GetDriverByName('OSM')
data = driver.Open('inner_richmond.osm')
layer = data.GetLayer('points')

features=[x for x in layer]
print len(features)
# Out:
# 39

# %% [markdown]
# Next I loop through each of these point features and extract some attributes, including the location. I convert the feature attributes to JSON and extract the feature name; the feature 'Highway' properties (relevant for bus stops, traffic signals, etc); the "Amenity" description (if relevant); and the lat/long coordinates. I use the coordinates to create ```shapely``` geometry objects and build a GeoDataFrame with the extracted data. Depending on the attributes of interest, you may need to tweak this code to obtain other information within the "other_tags" category.

# %%
data_list=[]
for feature in features:
    data=feature.ExportToJson(as_object=True)
    coords=data['geometry']['coordinates']
    shapely_geo=Point(coords[0],coords[1])
    name=data['properties']['name']
    highway=data['properties']['highway']
    other_tags=data['properties']['other_tags']
    if other_tags and 'amenity' in other_tags:
        feat=[x for x in other_tags.split(',') if 'amenity' in x][0]
        amenity=feat[feat.rfind('>')+2:feat.rfind('"')]
    else:
        amenity=None
    data_list.append([name,highway,amenity,shapely_geo])
gdf=gpd.GeoDataFrame(data_list,columns=['Name','Highway','Amenity','geometry'],crs={'init': 'epsg:4326'}).to_crs(epsg=3310)

# %%
gdf.tail()
# Out:
#                    Name   Highway     Amenity  \
# 34           8th Avenue  bus_stop        None
# 35  Best and Fresh Food      None        None
# 36                 None      None        None
# 37     May Shun Trading      None        None
# 38           Grain D'or      None  restaurant
#
#                                          geometry
# 34  POINT (-216757.5129094814 -22895.74381802278)
# 35  POINT (-216785.1594229685 -23117.45584711386)
# 36  POINT (-216742.9049959361 -23116.90880399616)
# 37  POINT (-216809.4551698703 -23116.59043585416)
# 38  POINT (-216493.3926737724 -23108.28007747373)

# %% [markdown]
# I can then easily manipulate or query the data any way I normally would using Pandas/GeoPandas. Below, I extract the features that represent coffee shops or bars and plot them on a map using ```matplotlib```. If the data is needed in another format (shapefile, geojson, etc) it can easily be exported using the ```GeoDataFrame.to_file()``` method.

# %%
cafe_bar=gdf[gdf.Amenity.isin(['cafe','pub','bar'])]
cafe_bar
# Out:
#                         Name Highway Amenity  \
# 18                 Cafe Coco    None    cafe
# 21  Blue Danube Coffee House    None    cafe
# 25               Rockit Room    None     bar
# 26            The Bitter End    None     pub
# 28              Ireland's 32    None     pub
#
#                                          geometry
# 18  POINT (-216737.0424637551 -23366.19233996468)
# 21  POINT (-216562.6742979415 -23112.86356830364)
# 25  POINT (-216668.2580983618 -23113.41150188772)
# 26  POINT (-216689.4750393766 -23143.02973108692)
# 28  POINT (-216469.8690838547 -23316.07564048655)

# %%
fig, ax = plt.subplots(figsize=(10,10))
for i,row in cafe_bar.iterrows():
    x=row['geometry'].x
    y=row['geometry'].y
    plt.annotate(row['Name'], xy=(x,y), size=13, xytext=(0,5), textcoords='offset points')
    plt.plot(x,y,'o', color='#f16824')
    ax.set(aspect=1)
title=plt.title('Inner Richmond Bars and Cafes',size=16)

# %% [markdown]
# And there you have it! Again, with large datasets it would be more appropriate to use a tool that directly imports the OSM data into a spatial database. However, this is a really quick and easy way to extract smaller amounts of data if needed!
